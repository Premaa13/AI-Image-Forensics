# %% [markdown]
# # Train EfficientNet for AI vs Real Image Detection
#
# **Purpose:** Train EfficientNet-B0 to classify images as AI-generated or Real.
# **Output:** Save checkpoint to `/kaggle/working/` for download, then place in `backend/models/checkpoints/efficientnet_ai_detector.pt`

# %%
# Import dependencies - add torch, torchvision, PIL, etc.
# Configure device (cuda/mps/cpu)
# Load dataset from /kaggle/input/... (adjust path to your dataset)

# %%
# Build EfficientNet-B0 with 2-class classifier (Real, AI-generated)
# Use transforms: Resize(224), ToTensor(), Normalize(ImageNet mean/std)
# Define DataLoader for train/val splits

# %%
# Training loop: cross-entropy loss, Adam optimizer
# Validate and save best model to /kaggle/working/efficientnet_ai_detector.pt
# Save state_dict or {"model_state_dict": model.state_dict()} for backend compatibility
